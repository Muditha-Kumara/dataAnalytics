# %%
# Project 3: Time Series Analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBRegressor

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
## Data preparation and visualization
def Data_Index(df):
    df['DATE'] = pd.to_datetime(df['DATE'], errors='coerce')
    df = df.set_index('DATE')
    return df


def Data_visualization(df):
    plt.figure(figsize=(12, 6))
    plt.title("Electric Production Over Time")
    plt.plot(df.index, df["IPG2211A2N"], linestyle="-")
    plt.xlabel("Date")
    plt.ylabel("Electric Production")
    plt.grid(True)
    plt.show()

# %%
## Feature engineering

def Make_Baseline_features(df):
    df = df.copy()
    df["year"] = df.index.year
    df["month"] = df.index.month
    df["quarter"] = df.index.quarter
    return df


def Make_Lag_features(df):
    df = df.copy()
    df["lag_1"] = df["IPG2211A2N"].shift(1)
    df["lag_2"] = df["IPG2211A2N"].shift(2)
    df["lag_3"] = df["IPG2211A2N"].shift(3)
    return df


def Rolling_means(df):
    df = df.copy()
    shifted_production = df["IPG2211A2N"].shift(1)
    df["rolling_mean_3"] = shifted_production.rolling(window=3, min_periods=1).mean()
    df["rolling_mean_6"] = shifted_production.rolling(window=6, min_periods=1).mean()
    return df


def add_exponential_smoothing(df):
    df = df.copy()
    shifted_production = df["IPG2211A2N"].shift(1)
    df["exponential_smoothing"] = shifted_production.ewm(span=3, adjust=False).mean()
    return df

# %%
## Load data and create features
df = pd.read_csv("Electric_Production.csv")

df = Data_Index(df)
df = Make_Baseline_features(df)
df = Make_Lag_features(df)
df = Rolling_means(df)
df = add_exponential_smoothing(df)

df = df.dropna()

df.head()
# Out:
#             IPG2211A2N  year  month  quarter    lag_1    lag_2    lag_3  \
# DATE
# 1985-04-01     57.4714  1985      4        2  62.4502  70.6720  72.5052
# 1985-05-01     55.3151  1985      5        2  57.4714  62.4502  70.6720
# 1985-06-01     58.0904  1985      6        2  55.3151  57.4714  62.4502
# 1985-07-01     62.6202  1985      7        3  58.0904  55.3151  57.4714
# 1985-08-01     63.2485  1985      8        3  62.6202  58.0904  55.3151
#
#             rolling_mean_3  rolling_mean_6  exponential_smoothing
# DATE
# 1985-04-01       68.542467       68.542467              67.019400
# 1985-05-01       63.531200       65.774700              62.245400
# 1985-06-01       58.412233       63.682780              58.780250
# 1985-07-01       56.958967       62.750717              58.435325
# 1985-08-01       58.675233       61.103217              60.527763

# %%
## Anomaly detection and removal

from scipy import stats

# Calculate z-scores
z_scores = np.abs(stats.zscore(df["IPG2211A2N"]))

# Mark anomalies
df["anomaly"] = z_scores > 3

# Print number of anomalies
print(f"Number of anomalies detected: {df['anomaly'].sum()}")

# Visualize anomalies
plt.figure(figsize=(12, 6))
plt.plot(df.index, df["IPG2211A2N"], label="Normal", color="blue")
plt.scatter(
    df[df["anomaly"]].index,
    df[df["anomaly"]]["IPG2211A2N"],
    color="red",
    label="Anomaly",
)
plt.title("Anomaly Detection in Electric Production")
plt.xlabel("Date")
plt.ylabel("Electric Production")
plt.legend()
plt.show()

# Remove anomalies for further analysis
print("Rows before filtering:", len(df))
df = df[~df["anomaly"]]
df = df.drop(columns=["anomaly"])
print("Rows after filtering:", len(df))
# Out:
# Number of anomalies detected: 1
# Rows before filtering: 394
# Rows after filtering: 393

# %%
## Visualize the time series
Data_visualization(df)

# %%
## Train-test split and evaluation
def Train_test_split_function(df, target, features):
    X = df[features]
    y = df[target]
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, train_size=0.8, shuffle=False
    )
    return X, y, X_train, X_test, y_train, y_test


def Evaluate_model_performance(y_test, y_pred):
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    print(f"MSE: {mse:.2f}")
    print(f"RMSE: {rmse:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"R2: {r2:.2f}")
    return mae, mse, rmse, r2

# %%
## XGBoost model
def XGBoost_Model():
    model = XGBRegressor(
        n_estimators=300,
        learning_rate=0.1,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    )
    return model

df_model = df.dropna().copy()

target = "IPG2211A2N"
features = [col for col in df_model.columns if col != target]

model = XGBoost_Model()
X, y, X_train, X_test, y_train, y_test = Train_test_split_function(df_model, target, features)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("XGBoost Results")
xgb_mae, xgb_mse, xgb_rmse, xgb_r2 = Evaluate_model_performance(y_test, y_pred)
# Out:
# XGBoost Results
# MSE: 21.41
# RMSE: 4.63
# MAE: 3.50
# R2: 0.77

# %%
## XGBoost feature importance and prediction visualization
def XGBoost_Feature_importance(model, X):
    importance = model.feature_importances_
    feature_importance = pd.DataFrame({
        "feature": X.columns,
        "importance": importance
    })
    feature_importance = feature_importance.sort_values(by="importance", ascending=False)
    return feature_importance


def Visualize_XGBoost_Feature_importance(feature_importance):
    plt.figure(figsize=(10, 6))
    plt.barh(feature_importance["feature"], feature_importance["importance"])
    plt.gca().invert_yaxis()
    plt.title("XGBoost Feature Importance Score")
    plt.xlabel("Feature Importance")
    plt.show()


def Actual_vs_Predicted_Visualize(y_test, y_pred, X_test):
    results = y_test.to_frame(name="actual").copy()
    results["predicted"] = y_pred
    results.index = X_test.index
    return results


def Visualize_Actual_vs_Predicted(results):
    plt.figure(figsize=(14, 6))
    plt.plot(results.index, results["actual"], label="Actual", linewidth=2)
    plt.plot(results.index, results["predicted"], label="Predicted", linewidth=2)
    plt.title("Actual vs Predicted")
    plt.xlabel("Date")
    plt.ylabel("Electric Production")
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()


feature_importance = XGBoost_Feature_importance(model, X_train)
Visualize_XGBoost_Feature_importance(feature_importance)

results = Actual_vs_Predicted_Visualize(y_test, y_pred, X_test)
Visualize_Actual_vs_Predicted(results)

# %%
## Random Forest model
def random_forest_model():
    return RandomForestRegressor(
        n_estimators=500,
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        max_features="sqrt",
        bootstrap=True,
        n_jobs=-1,
        random_state=42
    )

df_rf = df.dropna().copy()

target = "IPG2211A2N"
features = [c for c in df_rf.columns if c != target]

X, y, X_train, X_test, y_train, y_test = Train_test_split_function(df_rf, target, features)

model_rf = random_forest_model()
model_rf.fit(X_train, y_train)

y_pred_rf = model_rf.predict(X_test)
print("Random Forest Results")
rf_mae, rf_mse, rf_rmse, rf_r2 = Evaluate_model_performance(y_test, y_pred_rf)
# Out:
# Random Forest Results
# MSE: 23.18
# RMSE: 4.81
# MAE: 3.58
# R2: 0.75

# %%
## Linear Regression model
def linear_regression_forecast():
    lr_model = LinearRegression()
    return lr_model

df_lr = df.dropna().copy()

target = "IPG2211A2N"
features = [col for col in df_lr.columns if col != target]

model_lr = linear_regression_forecast()
X, y, X_train, X_test, y_train, y_test = Train_test_split_function(df_lr, target, features)

model_lr.fit(X_train, y_train)

y_pred_lr = model_lr.predict(X_test)
print("Linear Regression Results")
lr_mae, lr_mse, lr_rmse, lr_r2 = Evaluate_model_performance(y_test, y_pred_lr)
# Out:
# Linear Regression Results
# MSE: 131.81
# RMSE: 11.48
# MAE: 10.21
# R2: -0.42

# %%
## LSTM model

def split_data(df):
    split_index = int(len(df) * 0.8)
    train = df.iloc[:split_index]
    test = df.iloc[split_index:]
    return train, test


def create_dataset(dataset, time_steps=1):
    X, y = [], []
    for i in range(len(dataset) - time_steps):
        a = dataset[i:(i + time_steps), 0]
        X.append(a)
        y.append(dataset[i + time_steps, 0])
    return np.array(X), np.array(y)


def lstm_forecast(train, test):
    data_train = train["IPG2211A2N"].values.reshape(-1, 1)
    data_test = test["IPG2211A2N"].values.reshape(-1, 1)

    scaler = MinMaxScaler()
    data_train_normalized = scaler.fit_transform(data_train)
    data_test_normalized = scaler.transform(data_test)

    time_steps = 3

    X_train, y_train = create_dataset(data_train_normalized, time_steps)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

    lstm_model = Sequential()
    lstm_model.add(LSTM(units=50, input_shape=(X_train.shape[1], 1)))
    lstm_model.add(Dense(1))
    lstm_model.compile(optimizer="adam", loss="mean_squared_error")
    lstm_model.fit(X_train, y_train, epochs=5, batch_size=1, verbose=0)

    X_test, y_test = create_dataset(data_test_normalized, time_steps)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

    lstm_predictions = lstm_model.predict(X_test, verbose=0)
    lstm_predictions = scaler.inverse_transform(lstm_predictions)

    y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

    lstm_mse = mean_squared_error(y_test_actual, lstm_predictions)
    lstm_mae = mean_absolute_error(y_test_actual, lstm_predictions)
    lstm_rmse = np.sqrt(lstm_mse)
    lstm_r2 = r2_score(y_test_actual, lstm_predictions)

    print(f"MSE: {lstm_mse:.2f}")
    print(f"RMSE: {lstm_rmse:.2f}")
    print(f"MAE: {lstm_mae:.2f}")
    print(f"R2: {lstm_r2:.2f}")

    return lstm_model, y_test_actual, lstm_predictions, lstm_mae, lstm_mse, lstm_rmse, lstm_r2

# %%
df_lstm = df.dropna().copy()
train, test = split_data(df_lstm)

lstm_model, y_test_actual, lstm_predictions, lstm_mae, lstm_mse, lstm_rmse, lstm_r2 = lstm_forecast(train, test)
# Out:
# /home/muditha/dataAnalytics/venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# MSE: 91.71
# RMSE: 9.58
# MAE: 7.86
# R2: 0.01

# %%
# Collect model outputs into a DataFrame and plot as bar chart
import matplotlib.pyplot as plt
import pandas as pd

# Each model: Linear Regression, Random Forest, XGBoost, LSTM
model_names = ['Linear Regression', 'Random Forest', 'XGBoost', 'LSTM']
mae_values = [lr_mae, rf_mae, xgb_mae, lstm_mae]
mse_values = [lr_mse, rf_mse, xgb_mse, lstm_mse]
rmse_values = [lr_rmse, rf_rmse, xgb_rmse, lstm_rmse]
r2_values = [lr_r2, rf_r2, xgb_r2, lstm_r2]

results = pd.DataFrame({
    'Model': model_names,
    'MAE': mae_values,
    'MSE': mse_values,
    'RMSE': rmse_values,
    'R2': r2_values
})

# Plot bar chart for each metric
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
metrics = ['MAE', 'MSE', 'RMSE', 'R2']
for ax, metric in zip(axs.flat, metrics):
    ax.bar(results['Model'], results[metric], color='skyblue')
    ax.set_title(f'{metric} by Model')
    ax.set_ylabel(metric)
    ax.set_xlabel('Model')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
