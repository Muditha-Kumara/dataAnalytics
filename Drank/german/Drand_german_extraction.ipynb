# %% [markdown]
# # GT Keyword Extraction and Processing Workflow

# %%
# Configuration for German website
dataset_name = "german"
dataset_language = "german"
base_url = f"https://cs.uef.fi/~himat/WebRank/dataset_12/dataset_12/{dataset_name}"
num_pages = 86

# Stemming and Stopword Libraries for German
from nltk.stem.snowball import SnowballStemmer
import nltk
from nltk.corpus import stopwords  # Stopword library

# Initialize stemmer and stopwords for German
stemmer = SnowballStemmer(dataset_language)
nltk_german_stopwords = set(stopwords.words(dataset_language))

# Tag rating set (updated values for German)
tag_rating_set = {
    "URL": 15.7250,
    "h1": 0.3333,
    "head": 0.3333,
    "title": 0.3333,
    "th": 0.2000,
}

# %%
import re
def process_keywords(keywords):
    """Apply cleaning, stemming, and stopword filtering to a list of keywords. Returns a processed list of useful words."""
    processed = []
    for word in keywords:
        # Clean word: keep only alphabetic characters (including German letters)
        cleaned_word = re.sub(r'[^a-zA-ZäöüßÄÖÜẞ]', '', word)
        if not cleaned_word:
            continue
        # Stem word
        stemmed_word = stemmer.stem(cleaned_word)
        # Filter stopwords
        if stemmed_word not in nltk_german_stopwords:
            processed.append(stemmed_word)
    # Return unique processed keywords (useful words only)
    return list(set(processed))

# %%
from bs4 import BeautifulSoup
def extract_and_process_keywords_from_tag(html_text, tag_name):
    """Extracts keywords from the content inside the specified tag in the given HTML text, processes them using process_keywords, and returns a dictionary with keyword frequencies."""
    soup = BeautifulSoup(html_text, 'html.parser')
    elements = soup.find_all(tag_name)
    raw_keywords = []
    for elem in elements:
        text = elem.get_text(separator=' ')
        raw_keywords.extend(text.split())
    processed = process_keywords(raw_keywords)
    freq = {}
    for kw in processed:
        freq[kw] = freq.get(kw, 0) + 1
    return freq

# %%
# 5. Aggregate and Print URL Ratings Across All Pages (as a pseudo-tag for sorting)
from urllib.parse import urlparse, unquote
from collections import defaultdict
import urllib.request
import matplotlib.pyplot as plt

frequency_weight = 2

# Store metrics for all pages
dataset_precisions = []
dataset_recalls = []
dataset_f1s = []

for i in range(num_pages):
    gt_url = f"{base_url}/{i}/GT.txt"
    web_page_url = f"{base_url}/{i}"
    url_file_url = f"{base_url}/{i}/URL.txt"
    processed_gt_keywords = []
    extracting_keywords = {}
    headers = {"User-Agent": "Mozilla/5.0 (compatible; Copilot/1.0)"}
    gt_req = urllib.request.Request(gt_url, headers=headers)
    web_req = urllib.request.Request(web_page_url, headers=headers)
    url_req = urllib.request.Request(url_file_url, headers=headers)
    try:
        with urllib.request.urlopen(gt_req, timeout=5) as response:
            gt_text = response.read().decode("utf-8-sig").strip()
            gt_keywords = gt_text.split()
            processed_gt_keywords = list(set(process_keywords(gt_keywords)))
    except Exception as e:
        continue
    # HTML tag ratings
    try:
        with urllib.request.urlopen(web_req, timeout=5) as web_response:
            html_text = web_response.read().decode("utf-8-sig").strip()

            for tag, rating in tag_rating_set.items():
                result = extract_and_process_keywords_from_tag(html_text, tag)
                for kw, freq in result.items():
                    value = rating + freq * frequency_weight
                    if kw in extracting_keywords:
                        extracting_keywords[kw] += value
                    else:
                        extracting_keywords[kw] = value
    except Exception as e:
        continue
    # URL rating as a pseudo-tag
    try:
        with urllib.request.urlopen(url_req, timeout=5) as url_response:
            real_url = url_response.read().decode("utf-8-sig").strip()
            parsed_url = urlparse(real_url)
            normalized_path = unquote(parsed_url.path.lower())
            url_tokens = re.findall(r"[a-zåäöA-ZÅÄÖ0-9]+", normalized_path)
            processed_url_keywords = process_keywords(url_tokens)
            # Use the same scoring pattern as tags, with 'URL' rating
            url_rating = tag_rating_set.get('URL', 0)
            for kw in processed_url_keywords:
                value = url_rating  # treat each URL keyword as freq=1
                if kw in extracting_keywords:
                    extracting_keywords[kw] += value
                else:
                    extracting_keywords[kw] = value
    except Exception as e:
        continue
    # Calculate Precision, Recall, and F1-score
    top_10 = sorted(extracting_keywords.items(), key=lambda x: x[1], reverse=True)[:10]
    extracted_keywords = set([kw for kw, _ in top_10])
    gt_keywords_set = set(processed_gt_keywords)

    # Calculate metrics
    true_positives = len(extracted_keywords & gt_keywords_set)
    precision = true_positives / len(extracted_keywords) if len(extracted_keywords) > 0 else 0
    recall = true_positives / len(gt_keywords_set) if len(gt_keywords_set) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    dataset_precisions.append(precision)
    dataset_recalls.append(recall)
    dataset_f1s.append(f1_score)

    print(f"Page {i}: Precision={precision:.4f}, Recall={recall:.4f}, F1={f1_score:.4f}")

# Visualize and compare performance
plt.figure(figsize=(12, 6))
plt.plot(dataset_precisions, label='Precision', marker='o')
plt.plot(dataset_recalls, label='Recall', marker='s')
plt.plot(dataset_f1s, label='F1-score', marker='^')
plt.xlabel('Page Index')
plt.ylabel('Score')
plt.title('Keyword Extraction Performance Across Pages')
plt.legend()
plt.grid(True)
plt.show()

# Print average metrics
print(f"\nAverage Precision: {sum(dataset_precisions)/len(dataset_precisions):.4f}")
print(f"Average Recall: {sum(dataset_recalls)/len(dataset_recalls):.4f}")
print(f"Average F1-score: {sum(dataset_f1s)/len(dataset_f1s):.4f}")
# Out:
# Page 0: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 1: Precision=0.2000, Recall=0.5000, F1=0.2857
# Page 2: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 3: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 4: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 5: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 6: Precision=0.1111, Recall=0.1000, F1=0.1053
# Page 7: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 8: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 9: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 10: Precision=0.1000, Recall=0.2500, F1=0.1429
# Page 11: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 12: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 13: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 14: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 15: Precision=0.1000, Recall=0.0139, F1=0.0244
# Page 16: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 17: Precision=0.6000, Recall=0.3750, F1=0.4615
# Page 18: Precision=0.3000, Recall=0.0750, F1=0.1200
# Page 19: Precision=0.4000, Recall=0.1081, F1=0.1702
# Page 20: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 21: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 22: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 23: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 24: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 25: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 26: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 27: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 28: Precision=0.1250, Recall=0.0400, F1=0.0606
# Page 29: Precision=0.1250, Recall=0.0909, F1=0.1053
# Page 30: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 31: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 32: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 33: Precision=0.1111, Recall=0.0385, F1=0.0571
# Page 34: Precision=0.2000, Recall=0.2857, F1=0.2353
# Page 35: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 36: Precision=0.3000, Recall=0.7500, F1=0.4286
# Page 37: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 38: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 39: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 40: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 41: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 42: Precision=0.1000, Recall=0.0833, F1=0.0909
# Page 43: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 44: Precision=0.2000, Recall=0.4000, F1=0.2667
# Page 45: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 46: Precision=0.3000, Recall=0.6000, F1=0.4000
# Page 47: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 48: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 49: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 50: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 51: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 52: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 53: Precision=0.2000, Recall=0.1111, F1=0.1429
# Page 54: Precision=0.2000, Recall=0.1053, F1=0.1379
# Page 55: Precision=0.2000, Recall=0.1429, F1=0.1667
# Page 56: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 57: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 58: Precision=0.1000, Recall=0.2500, F1=0.1429
# Page 59: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 60: Precision=0.2000, Recall=0.1250, F1=0.1538
# Page 61: Precision=0.2000, Recall=0.2000, F1=0.2000
# Page 62: Precision=0.1000, Recall=0.1111, F1=0.1053
# Page 63: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 64: Precision=0.2000, Recall=0.2857, F1=0.2353
# Page 65: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 66: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 67: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 68: Precision=0.1000, Recall=0.3333, F1=0.1538
# Page 69: Precision=0.3000, Recall=0.5000, F1=0.3750
# Page 70: Precision=0.1000, Recall=0.3333, F1=0.1538
# Page 71: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 72: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 73: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 74: Precision=0.3000, Recall=0.1579, F1=0.2069
# Page 75: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 76: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 77: Precision=0.2000, Recall=0.1250, F1=0.1538
# Page 78: Precision=0.2000, Recall=0.2857, F1=0.2353
# Page 79: Precision=0.2000, Recall=0.4000, F1=0.2667
# Page 80: Precision=0.1000, Recall=0.1429, F1=0.1176
# Page 81: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 82: Precision=0.1000, Recall=0.3333, F1=0.1538
# Page 83: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 84: Precision=0.0000, Recall=0.0000, F1=0.0000
# Page 85: Precision=0.0000, Recall=0.0000, F1=0.0000
# Average Precision: 0.0729
# Average Recall: 0.0890
# Average F1-score: 0.0704
